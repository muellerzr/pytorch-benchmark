# %%
! pip install datasets transformers
! pip install cloud-tpu-client==0.10 torch==1.9.0 https://storage.googleapis.com/tpu-pytorch/wheels/torch_xla-1.9-cp37-cp37m-linux_x86_64.whl
! pip install accelerate

# %%
# !git clone https://github.com/muellerzr/pytorch-benchmark.git

# %%
# %cd pytorch-benchmark/scripts
# !pip install .

# %%
# %cd pytorch-benchmark/scripts
# !accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/baseline.yml --iteration=1
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 18:35:15.165444: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 18:35:52.433252: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 18:35:52.494681: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 18:35:52.573582: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# %cd pytorch-benchmark/scripts
# !accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/baseline.yml --iteration=2
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 18:40:13.690240: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 18:40:51.322416: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 18:40:51.530753: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 18:40:51.550940: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# %cd pytorch-benchmark/scripts
# !accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/baseline.yml --iteration=3
import os; os._exit(00)

# %%
# %cd pytorch-benchmark/scripts
# !accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/mixed_precision.yml --iteration=1
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 18:49:07.977241: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 18:49:44.660555: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 18:49:44.689006: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 18:49:44.696274: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# %cd pytorch-benchmark/scripts
# !accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/mixed_precision.yml --iteration=2
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 18:54:18.894058: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 18:54:55.812341: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 18:54:55.906985: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 18:54:55.919269: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# %cd pytorch-benchmark/scripts
# !accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/mixed_precision.yml --iteration=3
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 18:57:03.411773: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 18:57:44.008017: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 18:57:44.051313: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 18:57:44.062379: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# %cd pytorch-benchmark/scripts
# !accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/adjusted_bs.yml --iteration=1
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:00:42.832003: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:01:19.970777: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:01:20.011707: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:01:20.090235: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# %cd pytorch-benchmark/scripts
# !accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/adjusted_bs.yml --iteration=2
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:10:20.992408: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:10:57.614770: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:10:57.683034: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:10:57.712325: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# !zip -r pytorch_benchmark.zip pytorch-benchmark

# %%
# %cd pytorch-benchmark/scripts
# !accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/adjusted_bs.yml --iteration=3
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:14:53.658443: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:15:30.216278: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:15:30.216841: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:15:30.334273: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# %cd pytorch-benchmark/scripts
# !accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/adjusted_bs_mixed_precision.yml --iteration=1
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:19:27.109611: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:20:03.469885: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:20:03.482137: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:20:03.505987: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# %cd pytorch-benchmark/scripts
# !accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/adjusted_bs_mixed_precision.yml --iteration=2
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:25:16.192959: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:25:55.872332: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:25:55.913195: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:25:55.986322: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# %cd pytorch-benchmark/scripts
# !accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/adjusted_bs_mixed_precision.yml --iteration=3
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:28:47.749056: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:29:25.027626: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:29:25.176248: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:29:25.182727: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# %cd pytorch-benchmark/scripts
# !accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/adjusted_bs_eightfold_lr.yml --iteration=1
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:32:34.498958: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:33:11.940351: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:33:12.098099: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:33:12.105379: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# %cd pytorch-benchmark/scripts
# !accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/adjusted_bs_eightfold_lr.yml --iteration=2
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:36:26.596977: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:37:02.931020: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:37:03.042633: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:37:03.089890: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# %cd pytorch-benchmark/scripts
# !accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/adjusted_bs_eightfold_lr.yml --iteration=3
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:40:16.870004: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:40:53.257498: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:40:53.454797: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:40:53.510862: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# !zip -r pytorch_benchmark.zip pytorch-benchmark
# Out:
# updating: pytorch-benchmark/ (stored 0%)
# updating: pytorch-benchmark/README.md (deflated 42%)
# updating: pytorch-benchmark/MANIFEST.in (deflated 22%)
# updating: pytorch-benchmark/LICENSE (deflated 65%)
# updating: pytorch-benchmark/Makefile (deflated 42%)
# updating: pytorch-benchmark/pytorch_benchmark/ (stored 0%)
# updating: pytorch-benchmark/pytorch_benchmark/prepare.py (deflated 67%)
# updating: pytorch-benchmark/pytorch_benchmark/__init__.py (deflated 37%)
# updating: pytorch-benchmark/pytorch_benchmark/_nbdev.py (deflated 63%)
# updating: pytorch-benchmark/pytorch_benchmark/utils.py (deflated 61%)
# updating: pytorch-benchmark/pytorch_benchmark/imports.py (deflated 57%)
# updating: pytorch-benchmark/settings.ini (deflated 48%)
# updating: pytorch-benchmark/setup.py (deflated 58%)
# updating: pytorch-benchmark/nbs/ (stored 0%)
# updating: pytorch-benchmark/nbs/01_prepare.ipynb (deflated 74%)
# updating: pytorch-benchmark/nbs/02_utils.ipynb (deflated 71%)
# ...

# %%
# %cd pytorch-benchmark/scripts
# !accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/adjusted_bs_eightfold_lr_mixed_precision.yml --iteration=1
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:44:11.688243: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:44:48.812426: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:44:48.893437: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:44:48.956942: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# %cd pytorch-benchmark/scripts
# !accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/adjusted_bs_eightfold_lr_mixed_precision.yml --iteration=2
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:47:50.230691: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:48:27.803336: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:48:27.847311: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:48:27.850436: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# %cd pytorch-benchmark/scripts
# !accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/adjusted_bs_eightfold_lr_mixed_precision.yml --iteration=3
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:51:21.845658: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:51:58.648110: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:51:58.738347: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:51:58.907866: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# !zip -r pytorch_benchmark.zip pytorch-benchmark

# %%
# %cd pytorch-benchmark/scripts
# !XLA_USE_BF16=0 XLA_DOWNCAST_BF16=1 accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/mixed_precision_downcast.yml --iteration=1
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:55:42.875392: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:56:19.334422: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:56:19.412102: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:56:19.423221: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# %cd pytorch-benchmark/scripts
# !XLA_USE_BF16=0 XLA_DOWNCAST_BF16=1 accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/mixed_precision_downcast.yml --iteration=2
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:58:52.051603: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 19:59:28.841407: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:59:28.853852: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 19:59:28.861436: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# %cd pytorch-benchmark/scripts
# !XLA_USE_BF16=0 XLA_DOWNCAST_BF16=1 accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/mixed_precision_downcast.yml --iteration=3
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 20:02:03.739838: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 20:02:40.812826: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 20:02:41.025671: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 20:02:41.142899: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# %cd pytorch-benchmark/scripts
# !XLA_USE_BF16=0 XLA_DOWNCAST_BF16=1 accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/adjusted_bs_mixed_precision_downcast.yml --iteration=1
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 20:05:08.771962: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 20:05:45.752122: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 20:05:45.803887: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 20:05:45.807625: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# %cd pytorch-benchmark/scripts
# !XLA_USE_BF16=0 XLA_DOWNCAST_BF16=1 accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/adjusted_bs_mixed_precision_downcast.yml --iteration=2
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 20:09:02.379154: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 20:09:38.660704: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 20:09:38.755205: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 20:09:38.865485: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# %cd pytorch-benchmark/scripts
# !XLA_USE_BF16=0 XLA_DOWNCAST_BF16=1 accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/adjusted_bs_mixed_precision_downcast.yml --iteration=3
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 20:15:04.699494: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 20:15:41.872800: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 20:15:41.960007: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 20:15:41.969537: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# %cd pytorch-benchmark/scripts/
# !XLA_USE_BF16=0 XLA_DOWNCAST_BF16=1 accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/adjusted_bs_eightfold_lr_mixed_precision_downcast.yml --iteration=1
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 20:21:22.519976: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 20:21:59.443932: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 20:21:59.450438: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 20:21:59.490435: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# %cd pytorch-benchmark/scripts
# !XLA_USE_BF16=0 XLA_DOWNCAST_BF16=1 accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/adjusted_bs_eightfold_lr_mixed_precision_downcast.yml --iteration=2
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 20:26:10.028920: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 20:26:46.570555: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 20:26:46.573052: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 20:26:46.600169: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# %cd pytorch-benchmark/scripts
# !XLA_USE_BF16=0 XLA_DOWNCAST_BF16=1 accelerate launch nlp_script_accelerate.py configs/nlp_script/tpu/adjusted_bs_eightfold_lr_mixed_precision_downcast.yml --iteration=3
import os; os._exit(00)
# Out:
# /content/pytorch-benchmark/scripts
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 20:30:40.911550: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# WARNING:root:TPU has started up successfully with version pytorch-1.9
# 2022-07-19 20:31:17.884734: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 20:31:17.963645: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# 2022-07-19 20:31:18.007674: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %%
# !zip -r pytorch_benchmark.zip pytorch-benchmark
# Out:
# updating: pytorch-benchmark/ (stored 0%)
# updating: pytorch-benchmark/README.md (deflated 42%)
# updating: pytorch-benchmark/MANIFEST.in (deflated 22%)
# updating: pytorch-benchmark/LICENSE (deflated 65%)
# updating: pytorch-benchmark/Makefile (deflated 42%)
# updating: pytorch-benchmark/pytorch_benchmark/ (stored 0%)
# updating: pytorch-benchmark/pytorch_benchmark/prepare.py (deflated 67%)
# updating: pytorch-benchmark/pytorch_benchmark/__init__.py (deflated 37%)
# updating: pytorch-benchmark/pytorch_benchmark/_nbdev.py (deflated 63%)
# updating: pytorch-benchmark/pytorch_benchmark/utils.py (deflated 61%)
# updating: pytorch-benchmark/pytorch_benchmark/imports.py (deflated 57%)
# updating: pytorch-benchmark/settings.ini (deflated 48%)
# updating: pytorch-benchmark/setup.py (deflated 58%)
# updating: pytorch-benchmark/nbs/ (stored 0%)
# updating: pytorch-benchmark/nbs/01_prepare.ipynb (deflated 74%)
# updating: pytorch-benchmark/nbs/02_utils.ipynb (deflated 71%)
# ...
